# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# df = pd.read_csv('FINAL_USO.xls', sep='/n', nrows=2, engine='python')
df = pd.read_csv('FINAL_USO.csv', sep='/n', nrows=2, engine='python')
df
# Out:
#   Date,Open,High,Low,Close,Adj Close,Volume,SP_open,SP_high,SP_low,SP_close,SP_Ajclose,SP_volume,DJ_open,DJ_high,DJ_low,DJ_close,DJ_Ajclose,DJ_volume,EG_open,EG_high,EG_low,EG_close,EG_Ajclose,EG_volume,EU_Price,EU_open,EU_high,EU_low,EU_Trend,OF_Price,OF_Open,OF_High,OF_Low,OF_Volume,OF_Trend,OS_Price,OS_Open,OS_High,OS_Low,OS_Trend,SF_Price,SF_Open,SF_High,SF_Low,SF_Volume,SF_Trend,USB_Price,USB_Open,USB_High,USB_Low,USB_Trend,PLT_Price,PLT_Open,PLT_High,PLT_Low,PLT_Trend,PLD_Price,PLD_Open,PLD_High,PLD_Low,PLD_Trend,RHO_PRICE,USDI_Price,USDI_Open,USDI_High,USDI_Low,USDI_Volume,USDI_Trend,GDX_Open,GDX_High,GDX_Low,GDX_Close,GDX_Adj Close,GDX_Volume,USO_Open,USO_High,USO_Low,USO_Close,USO_Adj Close,USO_Volume
# 0  2011-12-15,154.740005,154.949997,151.710007000...
# 1  2011-12-16,154.309998,155.369995,153.899994,15...

# %%
# df = pd.read_csv('FINAL_USO.xls', sep=',', engine='python')
df = pd.read_csv('FINAL_USO.csv', sep=',', engine='python')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2011-12-15  154.740005  154.949997  151.710007  152.330002  152.330002
# 1     2011-12-16  154.309998  155.369995  153.899994  155.229996  155.229996
# 2     2011-12-19  155.479996  155.860001  154.360001  154.869995  154.869995
# 3     2011-12-20  156.820007  157.429993  156.580002  156.979996  156.979996
# 4     2011-12-21  156.979996  157.529999  156.130005  157.160004  157.160004
# ...          ...         ...         ...         ...         ...         ...
# 1713  2018-12-24  119.570000  120.139999  119.570000  120.019997  120.019997
# 1714  2018-12-26  120.620003  121.000000  119.570000  119.660004  119.660004
# 1715  2018-12-27  120.570000  120.900002  120.139999  120.570000  120.570000
# 1716  2018-12-28  120.800003  121.080002  120.720001  121.059998  121.059998
# 1717  2018-12-31  120.980003  121.260002  120.830002  121.250000  121.250000
#
#         Volume     SP_open     SP_high      SP_low  ...    GDX_Low  GDX_Close  \
# 0     21521900  123.029999  123.199997  121.989998  ...  51.570000  51.680000
# 1     18124300  122.230003  122.949997  121.300003  ...  52.040001  52.680000
# 2     12547200  122.059998  122.320000  120.029999  ...  51.029999  51.169998
# 3      9136300  122.180000  124.139999  120.370003  ...  52.369999  52.990002
# 4     11996100  123.930000  124.360001  122.750000  ...  52.419998  52.959999
# ...        ...         ...         ...         ...  ...        ...        ...
# 1713   9736400  239.039993  240.839996  234.270004  ...  20.650000  21.090000
# 1714  14293500  235.970001  246.179993  233.759995  ...  20.530001  20.620001
# 1715  11874400  242.570007  248.289993  238.960007  ...  20.700001  20.969999
# 1716   6864700  249.580002  251.399994  246.449997  ...  20.570000  20.600000
# 1717   8449400  249.559998  250.190002  247.470001  ...  20.559999  21.090000
#
#       GDX_Adj Close  GDX_Volume   USO_Open   USO_High    USO_Low  USO_Close  \
# 0         48.973877    20605600  36.900002  36.939999  36.049999  36.130001
# 1         49.921513    16285400  36.180000  36.500000  35.730000  36.270000
# 2         48.490578    15120200  36.389999  36.450001  35.930000  36.200001
# 3         50.215282    11644900  37.299999  37.610001  37.220001  37.560001
# 4         50.186852     8724300  37.669998  38.240002  37.520000  38.110001
# ...             ...         ...        ...        ...        ...        ...
# 1713      21.090000    60507000   9.490000   9.520000   9.280000   9.290000
# 1714      20.620001    76365200   9.250000   9.920000   9.230000   9.900000
# 1715      20.969999    52393000   9.590000   9.650000   9.370000   9.620000
# 1716      20.600000    49835000   9.540000   9.650000   9.380000   9.530000
# 1717      21.090000    53866600   9.630000   9.710000   9.440000   9.660000
#
#       USO_Adj Close  USO_Volume
# 0         36.130001    12616700
# 1         36.270000    12578800
# 2         36.200001     7418200
# 3         37.560001    10041600
# 4         38.110001    10728000
# ...             ...         ...
# 1713       9.290000    21598200
# 1714       9.900000    40978800
# 1715       9.620000    36578700
# 1716       9.530000    22803400
# 1717       9.660000    28417400
#
# [1718 rows x 81 columns]

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1718 non-null   object
#  1   open           1718 non-null   float64
#  2   high           1718 non-null   float64
#  3   low            1718 non-null   float64
#  4   close          1718 non-null   float64
#  5   adj close      1718 non-null   float64
#  6   volume         1718 non-null   int64
#  7   sp_open        1718 non-null   float64
#  8   sp_high        1718 non-null   float64
#  9   sp_low         1718 non-null   float64
#  10  sp_close       1718 non-null   float64
#  11  sp_ajclose     1718 non-null   float64
#  12  sp_volume      1718 non-null   int64
#  13  dj_open        1718 non-null   float64
#  14  dj_high        1718 non-null   float64
#  15  dj_low         1718 non-null   float64
#  16  dj_close       1718 non-null   float64
#  17  dj_ajclose     1718 non-null   float64
#  18  dj_volume      1718 non-null   int64
#  19  eg_open        1718 non-null   float64
#  20  eg_high        1718 non-null   float64
#  21  eg_low         1718 non-null   float64
#  22  eg_close       1718 non-null   float64
#  23  eg_ajclose     1718 non-null   float64
#  24  eg_volume      1718 non-null   int64
#  25  eu_price       1718 non-null   float64
#  26  eu_open        1718 non-null   float64
#  27  eu_high        1718 non-null   float64
#  28  eu_low         1718 non-null   float64
#  29  eu_trend       1718 non-null   int64
#  30  of_price       1718 non-null   float64
#  31  of_open        1718 non-null   float64
#  32  of_high        1718 non-null   float64
#  33  of_low         1718 non-null   float64
#  34  of_volume      1718 non-null   int64
#  35  of_trend       1718 non-null   int64
#  36  os_price       1718 non-null   float64
#  37  os_open        1718 non-null   float64
#  38  os_high        1718 non-null   float64
#  39  os_low         1718 non-null   float64
#  40  os_trend       1718 non-null   int64
#  41  sf_price       1718 non-null   int64
#  42  sf_open        1718 non-null   int64
#  43  sf_high        1718 non-null   int64
#  44  sf_low         1718 non-null   int64
#  45  sf_volume      1718 non-null   int64
#  46  sf_trend       1718 non-null   int64
#  47  usb_price      1718 non-null   float64
#  48  usb_open       1718 non-null   float64
#  49  usb_high       1718 non-null   float64
#  50  usb_low        1718 non-null   float64
#  51  usb_trend      1718 non-null   int64
#  52  plt_price      1718 non-null   float64
#  53  plt_open       1718 non-null   float64
#  54  plt_high       1718 non-null   float64
#  55  plt_low        1718 non-null   float64
#  56  plt_trend      1718 non-null   int64
#  57  pld_price      1718 non-null   float64
#  58  pld_open       1718 non-null   float64
#  59  pld_high       1718 non-null   float64
#  60  pld_low        1718 non-null   float64
#  61  pld_trend      1718 non-null   int64
#  62  rho_price      1718 non-null   int64
#  63  usdi_price     1718 non-null   float64
#  64  usdi_open      1718 non-null   float64
#  65  usdi_high      1718 non-null   float64
#  66  usdi_low       1718 non-null   float64
#  67  usdi_volume    1718 non-null   int64
#  68  usdi_trend     1718 non-null   int64
#  69  gdx_open       1718 non-null   float64
#  70  gdx_high       1718 non-null   float64
#  71  gdx_low        1718 non-null   float64
#  72  gdx_close      1718 non-null   float64
#  73  gdx_adj close  1718 non-null   float64
#  74  gdx_volume     1718 non-null   int64
#  75  uso_open       1718 non-null   float64
#  76  uso_high       1718 non-null   float64
#  77  uso_low        1718 non-null   float64
#  78  uso_close      1718 non-null   float64
#  79  uso_adj close  1718 non-null   float64
#  80  uso_volume     1718 non-null   int64
# dtypes: float64(58), int64(22), object(1)
# memory usage: 1.1+ MB

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#               open         high          low        close    adj close  \
# count  1718.000000  1718.000000  1718.000000  1718.000000  1718.000000
# mean    127.323434   127.854237   126.777695   127.319482   127.319482
# std      17.526993    17.631189    17.396513    17.536269    17.536269
# min     100.919998   100.989998   100.230003   100.500000   100.500000
# 25%     116.220001   116.540001   115.739998   116.052502   116.052502
# 50%     121.915001   122.325001   121.369999   121.795002   121.795002
# 75%     128.427494   129.087498   127.840001   128.470001   128.470001
# max     173.199997   174.070007   172.919998   173.610001   173.610001
#
#              volume      sp_open      sp_high       sp_low     sp_close  ...  \
# count  1.718000e+03  1718.000000  1718.000000  1718.000000  1718.000000  ...
# mean   8.446327e+06   204.490023   205.372637   203.487014   204.491222  ...
# std    4.920731e+06    43.831928    43.974644    43.618940    43.776999  ...
# min    1.501600e+06   122.059998   122.320000   120.029999   120.290001  ...
# 25%    5.412925e+06   170.392498   170.962506   169.577499   170.397500  ...
# 50%    7.483900e+06   205.464996   206.459999   204.430000   205.529999  ...
# 75%    1.020795e+07   237.292500   237.722500   236.147503   236.889996  ...
# max    9.380420e+07   293.089996   293.940002   291.809998   293.579987  ...
#
#            gdx_low    gdx_close  gdx_adj close    gdx_volume     uso_open  \
# count  1718.000000  1718.000000    1718.000000  1.718000e+03  1718.000000
# mean     26.384575    26.715012      25.924624  4.356515e+07    22.113417
# std      10.490908    10.603110       9.886570  2.909151e+07    11.431056
# min      12.400000    12.470000      12.269618  4.729000e+06     7.820000
# 25%      20.355000    20.585000      20.180950  2.259968e+07    11.420000
# 50%      22.870001    23.054999      22.677604  3.730465e+07    16.450000
# 75%      26.797500    27.317500      26.478154  5.697055e+07    34.419998
# max      56.770000    57.470001      54.617039  2.321536e+08    41.599998
#
#           uso_high      uso_low    uso_close  uso_adj close    uso_volume
# count  1718.000000  1718.000000  1718.000000    1718.000000  1.718000e+03
# mean     22.307148    21.904657    22.109051      22.109051  1.922313e+07
# std      11.478671    11.373997    11.432787      11.432787  1.575743e+07
# min       8.030000     7.670000     7.960000       7.960000  1.035100e+06
# 25%      11.500000    11.300000    11.392500      11.392500  6.229500e+06
# 50%      16.635001    16.040000    16.345000      16.345000  1.613015e+07
# 75%      34.667499    34.110000    34.417499      34.417499  2.672375e+07
# max      42.299999    41.299999    42.009998      42.009998  1.102657e+08
#
# [8 rows x 80 columns]

# %%
# reparieren

df['rho_price'].replace(0, np.nan, inplace=True)

df['rho_price'].interpolate(method='linear', limit_direction='both', inplace=True)

# %%
# Spalten
# Open Startwert          
# High Volativity
# Low Volativity
# Close   rausschmeißen
# Adj, Close  benutzen für Vorhersage

# X[t..t-365], V[t..t-365] -> Kategorie( Adj. Close [t+7])
# X(t0), V(t0) -> Kategorie(Adj. Close[t0+7])  funktioniert nicht

#  t0, t1, t2, random... 

# trainingsstop t0, >t0 Testdaten, <t0 Trainingsdaten
# t0 = 01.01.2016, vorhersagen 02.01.2016, 03.02.2016????
# loop für predict[daten vom 02.01].......

# %%
df.iloc[:,1:].corr()
# Out:
#                    open      high       low     close  adj close    volume  \
# open           1.000000  0.999515  0.999442  0.998976   0.998976  0.251921
# high           0.999515  1.000000  0.999262  0.999535   0.999535  0.261064
# low            0.999442  0.999262  1.000000  0.999532   0.999532  0.237031
# close          0.998976  0.999535  0.999532  1.000000   1.000000  0.246778
# adj close      0.998976  0.999535  0.999532  1.000000   1.000000  0.246778
# ...                 ...       ...       ...       ...        ...       ...
# uso_close      0.635138  0.637483  0.633994  0.635675   0.635675  0.081642
# uso_adj close  0.635138  0.637483  0.633994  0.635675   0.635675  0.081642
# uso_volume    -0.455920 -0.454913 -0.457628 -0.456193  -0.456193  0.069580
# y             -0.094732 -0.087458 -0.088870 -0.082588  -0.082588  0.009789
# volatility     0.119466  0.137351  0.099602  0.119040   0.119040  0.643049
#
#                 sp_open   sp_high    sp_low  sp_close  ...  gdx_adj close  \
# open          -0.684314 -0.684597 -0.683464 -0.683998  ...       0.974098
# high          -0.688118 -0.688365 -0.687325 -0.687817  ...       0.974746
# low           -0.680911 -0.681242 -0.679988 -0.680567  ...       0.974182
# close         -0.684618 -0.684904 -0.683750 -0.684284  ...       0.974980
# adj close     -0.684618 -0.684904 -0.683750 -0.684284  ...       0.974980
# ...                 ...       ...       ...       ...  ...            ...
# uso_close     -0.773099 -0.773957 -0.771928 -0.773159  ...       0.600756
# uso_adj close -0.773099 -0.773957 -0.771928 -0.773159  ...       0.600756
# uso_volume     0.375568  0.377996  0.371390  0.374658  ...      -0.421065
# y              0.018255  0.017712  0.017233  0.017144  ...      -0.038105
# volatility    -0.279305 -0.277028 -0.282705 -0.280359  ...       0.125043
#
#                gdx_volume  uso_open  uso_high   uso_low  uso_close  \
# open            -0.514230  0.634872  0.634864  0.634277   0.635138
# high            -0.508782  0.637101  0.637208  0.636538   0.637483
# low             -0.519988  0.633591  0.633623  0.633140   0.633994
# close           -0.514616  0.635197  0.635311  0.634732   0.635675
# adj close       -0.514616  0.635197  0.635311  0.634732   0.635675
# ...                   ...       ...       ...       ...        ...
# uso_close       -0.523801  0.999699  0.999867  0.999879   1.000000
# uso_adj close   -0.523801  0.999699  0.999867  0.999879   1.000000
# uso_volume       0.498816 -0.699000 -0.695678 -0.702665  -0.699221
# y                0.058175 -0.063700 -0.063977 -0.063929  -0.064059
# volatility       0.259574  0.168930  0.171089  0.166212   0.168730
#
#                uso_adj close  uso_volume         y  volatility
# open                0.635138   -0.455920 -0.094732    0.119466
# high                0.637483   -0.454913 -0.087458    0.137351
# low                 0.633994   -0.457628 -0.088870    0.099602
# close               0.635675   -0.456193 -0.082588    0.119040
# adj close           0.635675   -0.456193 -0.082588    0.119040
# ...                      ...         ...       ...         ...
# uso_close           1.000000   -0.699221 -0.064059    0.168730
# uso_adj close       1.000000   -0.699221 -0.064059    0.168730
# uso_volume         -0.699221    1.000000  0.036299    0.021764
# y                  -0.064059    0.036299  1.000000    0.030127
# volatility          0.168730    0.021764  0.030127    1.000000
#
# [82 rows x 82 columns]

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj close', 'volume',
#        'sp_open', 'sp_high', 'sp_low', 'sp_close', 'sp_ajclose', 'sp_volume',
#        'dj_open', 'dj_high', 'dj_low', 'dj_close', 'dj_ajclose', 'dj_volume',
#        'eg_open', 'eg_high', 'eg_low', 'eg_close', 'eg_ajclose', 'eg_volume',
#        'eu_price', 'eu_open', 'eu_high', 'eu_low', 'eu_trend', 'of_price',
#        'of_open', 'of_high', 'of_low', 'of_volume', 'of_trend', 'os_price',
#        'os_open', 'os_high', 'os_low', 'os_trend', 'sf_price', 'sf_open',
#        'sf_high', 'sf_low', 'sf_volume', 'sf_trend', 'usb_price', 'usb_open',
#        'usb_high', 'usb_low', 'usb_trend', 'plt_price', 'plt_open', 'plt_high',
#        'plt_low', 'plt_trend', 'pld_price', 'pld_open', 'pld_high', 'pld_low',
#        'pld_trend', 'rho_price', 'usdi_price', 'usdi_open', 'usdi_high',
#        'usdi_low', 'usdi_volume', 'usdi_trend', 'gdx_open', 'gdx_high',
#        'gdx_low', 'gdx_close', 'gdx_adj close', 'gdx_volume', 'uso_open',
#        'uso_high', 'uso_low', 'uso_close', 'uso_adj close', 'uso_volume'],
#       dtype='object')

# %%
open_columns = [col for col in df.columns if col.endswith('open')]

df_open = df[open_columns]
df_open.corr()
# Out:
#                open   sp_open   dj_open   eg_open   eu_open   of_open  \
# open       1.000000 -0.684314 -0.588615  0.863226  0.579304  0.708938
# sp_open   -0.684314  1.000000  0.986895 -0.904923 -0.547544 -0.623644
# dj_open   -0.588615  0.986895  1.000000 -0.858153 -0.478254 -0.536368
# eg_open    0.863226 -0.904923 -0.858153  1.000000  0.617570  0.747851
# eu_open    0.579304 -0.547544 -0.478254  0.617570  1.000000  0.903646
# of_open    0.708938 -0.623644 -0.536368  0.747851  0.903646  1.000000
# os_open    0.629795 -0.588846 -0.509771  0.693514  0.917800  0.986577
# sf_open    0.946454 -0.723397 -0.646593  0.871019  0.589482  0.733497
# usb_open  -0.441780  0.569394  0.606054 -0.496939  0.137909  0.091882
# plt_open   0.774171 -0.856400 -0.811351  0.905418  0.821155  0.868606
# pld_open  -0.215840  0.705105  0.772188 -0.477619  0.030700 -0.013852
# usdi_open -0.720350  0.690563  0.617681 -0.768505 -0.970858 -0.932543
# gdx_open   0.975510 -0.694470 -0.606360  0.882530  0.513457  0.673813
# uso_open   0.634872 -0.772902 -0.721395  0.812545  0.887138  0.945648
#
#             os_open   sf_open  usb_open  plt_open  pld_open  usdi_open  \
# open       0.629795  0.946454 -0.441780  0.774171 -0.215840  -0.720350
# sp_open   -0.588846 -0.723397  0.569394 -0.856400  0.705105   0.690563
# dj_open   -0.509771 -0.646593  0.606054 -0.811351  0.772188   0.617681
# eg_open    0.693514  0.871019 -0.496939  0.905418 -0.477619  -0.768505
# eu_open    0.917800  0.589482  0.137909  0.821155  0.030700  -0.970858
# of_open    0.986577  0.733497  0.091882  0.868606 -0.013852  -0.932543
# os_open    1.000000  0.663103  0.154064  0.844900  0.000759  -0.925338
# sf_open    0.663103  1.000000 -0.402050  0.807752 -0.291511  -0.718386
# usb_open   0.154064 -0.402050  1.000000 -0.300459  0.683016   0.048314
# plt_open   0.844900  0.807752 -0.300459  1.000000 -0.326000  -0.900993
# pld_open   0.000759 -0.291511  0.683016 -0.326000  1.000000   0.112992
# usdi_open -0.925338 -0.718386  0.048314 -0.900993  0.112992   1.000000
# gdx_open   0.599487  0.935474 -0.467911  0.744838 -0.266908  -0.667707
# uso_open   0.949870  0.671203 -0.045621  0.930378 -0.219059  -0.930830
#
#            gdx_open  uso_open
# open       0.975510  0.634872
# sp_open   -0.694470 -0.772902
# dj_open   -0.606360 -0.721395
# eg_open    0.882530  0.812545
# eu_open    0.513457  0.887138
# of_open    0.673813  0.945648
# os_open    0.599487  0.949870
# sf_open    0.935474  0.671203
# usb_open  -0.467911 -0.045621
# plt_open   0.744838  0.930378
# pld_open  -0.266908 -0.219059
# usdi_open -0.667707 -0.930830
# gdx_open   1.000000  0.615478
# uso_open   0.615478  1.000000

# %%
volume_columns = [col for col in df.columns if col.endswith('volume')]
df_volume = df[volume_columns]
df_volume.corr()
# Out:
#                volume  sp_volume  dj_volume  eg_volume  of_volume  sf_volume  \
# volume       1.000000   0.383677   0.015451   0.200292   0.027085   0.460602
# sp_volume    0.383677   1.000000  -0.005474   0.078210  -0.062737   0.400875
# dj_volume    0.015451  -0.005474   1.000000   0.361814   0.301286  -0.227824
# eg_volume    0.200292   0.078210   0.361814   1.000000   0.175614  -0.092254
# of_volume    0.027085  -0.062737   0.301286   0.175614   1.000000  -0.236133
# sf_volume    0.460602   0.400875  -0.227824  -0.092254  -0.236133   1.000000
# usdi_volume  0.141516   0.314075  -0.033662   0.059653   0.093027   0.045866
# gdx_volume   0.302225   0.022619   0.058096   0.311623   0.254377  -0.313608
# uso_volume   0.069580   0.045722   0.166826   0.128743   0.417824  -0.299516
#
#              usdi_volume  gdx_volume  uso_volume
# volume          0.141516    0.302225    0.069580
# sp_volume       0.314075    0.022619    0.045722
# dj_volume      -0.033662    0.058096    0.166826
# eg_volume       0.059653    0.311623    0.128743
# of_volume       0.093027    0.254377    0.417824
# sf_volume       0.045866   -0.313608   -0.299516
# usdi_volume     1.000000    0.218200    0.184919
# gdx_volume      0.218200    1.000000    0.498816
# uso_volume      0.184919    0.498816    1.000000

# %% [markdown]
# ### Berechnen einer neuen Zielspalte

# %%
# Berechnung einer neuen Zielspalte
# Veränderung des Goldpreises in den nächsten x (= predictdays) Tagen

class MyDataProcessor(): #TransformerMixin, BaseEstimator):
    def __init__(self, trainingsdays=5, predictdays=5):
        self.trainingsdays = trainingsdays
        self.predictdays = predictdays

    def fit(self, Xname='open',column_list=None):
        self.column_list_ = column_list
        #self.df_ = df
        self.Xname_ = Xname
        return self

    def transform(self, df):
        df_x = df[[self.Xname_]].rename(columns={self.Xname_:'X0'})
        for n in range(1, self.trainingsdays):
            df_x.loc[:,'dX'+str(-n)] = df_x.X0.shift(n-1) / df_x.X0.shift(n) -1
        if self.column_list_:
            df_x.loc[:, self.column_list_] = df.loc[:,self.column_list_]
        df_x.loc[:,'y'] = df_x.X0.shift(-self.predictdays) / df_x.X0 - 1
        # df_x.dropna(inplace=True)
        self.X_ = df_x.drop('y', axis=1)
        self.y_ = df_x.loc[:,['y']]
        return self

# %%
processor = MyDataProcessor(trainingsdays=0, predictdays=5)
processor.fit()
processor = processor.transform(df)

df["y"] = processor.y_
df["y"].tail(10)
# Out:
# 1708    0.018744
# 1709    0.023504
# 1710    0.019706
# 1711    0.014189
# 1712    0.015018
# 1713         NaN
# 1714         NaN
# 1715         NaN
# 1716         NaN
# 1717         NaN
# Name: y, dtype: float64

# %% [markdown]
# ### Neue Spalte Volatilität

# %%
df["volatility"] = (df["high"] - df["low"]) / df["open"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 83 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1718 non-null   datetime64[ns]
#  1   open           1718 non-null   float64
#  2   high           1718 non-null   float64
#  3   low            1718 non-null   float64
#  4   close          1718 non-null   float64
#  5   adj close      1718 non-null   float64
#  6   volume         1718 non-null   int64
#  7   sp_open        1718 non-null   float64
#  8   sp_high        1718 non-null   float64
#  9   sp_low         1718 non-null   float64
#  10  sp_close       1718 non-null   float64
#  11  sp_ajclose     1718 non-null   float64
#  12  sp_volume      1718 non-null   int64
#  13  dj_open        1718 non-null   float64
#  14  dj_high        1718 non-null   float64
#  15  dj_low         1718 non-null   float64
#  16  dj_close       1718 non-null   float64
#  17  dj_ajclose     1718 non-null   float64
#  18  dj_volume      1718 non-null   int64
#  19  eg_open        1718 non-null   float64
#  20  eg_high        1718 non-null   float64
#  21  eg_low         1718 non-null   float64
#  22  eg_close       1718 non-null   float64
#  23  eg_ajclose     1718 non-null   float64
#  24  eg_volume      1718 non-null   int64
#  25  eu_price       1718 non-null   float64
#  26  eu_open        1718 non-null   float64
#  27  eu_high        1718 non-null   float64
#  28  eu_low         1718 non-null   float64
#  29  eu_trend       1718 non-null   int64
#  30  of_price       1718 non-null   float64
#  31  of_open        1718 non-null   float64
#  32  of_high        1718 non-null   float64
#  33  of_low         1718 non-null   float64
#  34  of_volume      1718 non-null   int64
#  35  of_trend       1718 non-null   int64
#  36  os_price       1718 non-null   float64
#  37  os_open        1718 non-null   float64
#  38  os_high        1718 non-null   float64
#  39  os_low         1718 non-null   float64
#  40  os_trend       1718 non-null   int64
#  41  sf_price       1718 non-null   int64
#  42  sf_open        1718 non-null   int64
#  43  sf_high        1718 non-null   int64
#  44  sf_low         1718 non-null   int64
#  45  sf_volume      1718 non-null   int64
#  46  sf_trend       1718 non-null   int64
#  47  usb_price      1718 non-null   float64
#  48  usb_open       1718 non-null   float64
#  49  usb_high       1718 non-null   float64
#  50  usb_low        1718 non-null   float64
#  51  usb_trend      1718 non-null   int64
#  52  plt_price      1718 non-null   float64
#  53  plt_open       1718 non-null   float64
#  54  plt_high       1718 non-null   float64
#  55  plt_low        1718 non-null   float64
#  56  plt_trend      1718 non-null   int64
#  57  pld_price      1718 non-null   float64
#  58  pld_open       1718 non-null   float64
#  59  pld_high       1718 non-null   float64
#  60  pld_low        1718 non-null   float64
#  61  pld_trend      1718 non-null   int64
#  62  rho_price      1718 non-null   float64
#  63  usdi_price     1718 non-null   float64
#  64  usdi_open      1718 non-null   float64
#  65  usdi_high      1718 non-null   float64
#  66  usdi_low       1718 non-null   float64
#  67  usdi_volume    1718 non-null   int64
#  68  usdi_trend     1718 non-null   int64
#  69  gdx_open       1718 non-null   float64
#  70  gdx_high       1718 non-null   float64
#  71  gdx_low        1718 non-null   float64
#  72  gdx_close      1718 non-null   float64
#  73  gdx_adj close  1718 non-null   float64
#  74  gdx_volume     1718 non-null   int64
#  75  uso_open       1718 non-null   float64
#  76  uso_high       1718 non-null   float64
#  77  uso_low        1718 non-null   float64
#  78  uso_close      1718 non-null   float64
#  79  uso_adj close  1718 non-null   float64
#  80  uso_volume     1718 non-null   int64
#  81  y              1713 non-null   float64
#  82  volatility     0 non-null      float64
# dtypes: datetime64[ns](1), float64(61), int64(21)
# memory usage: 1.1 MB

# %%
df["volatility"].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: volatility, dtype: float64

# %% [markdown]
# ### Korrelation zum neuen Zielwert y

# %%
df['date'] = pd.to_datetime(df['date'])
all_corr = df.corr().abs()['y'].sort_values(ascending = False)
all_corr.iloc[:50]
# Out:
# y                1.000000
# plt_open         0.102210
# plt_low          0.101688
# plt_high         0.098823
# plt_trend        0.095754
# plt_price        0.095515
# open             0.094732
# sf_open          0.091507
# sf_low           0.090534
# usb_trend        0.089988
# sf_high          0.089390
# low              0.088870
# high             0.087458
# sf_price         0.085199
# close            0.082588
# adj close        0.082588
# eu_open          0.080833
# eu_high          0.080229
# eu_low           0.079333
# eu_price         0.076784
# of_price         0.075069
# of_high          0.074973
# of_low           0.074763
# of_open          0.074630
# usdi_open        0.074078
# os_price         0.073164
# usdi_low         0.072955
# usdi_high        0.072914
# os_low           0.072720
# os_high          0.072258
# os_open          0.072082
# usdi_price       0.070298
# uso_adj close    0.064059
# uso_close        0.064059
# uso_high         0.063977
# uso_low          0.063929
# uso_open         0.063700
# gdx_volume       0.058175
# usdi_trend       0.057628
# sf_trend         0.050335
# pld_open         0.049901
# pld_low          0.049356
# gdx_open         0.048025
# pld_price        0.046939
# pld_high         0.046904
# eg_open          0.046192
# usdi_volume      0.044608
# gdx_low          0.043943
# eg_low           0.043393
# eg_high          0.042790
# Name: y, dtype: float64

# %% [markdown]
# ### Korrelation zum Goldpreis "Close", absteigend

# %%
# df['Date'] = pd.to_datetime(df['Date'])
all_corr = df.corr().abs()['close'].sort_values(ascending = False)
all_corr[all_corr >= 0.5]
# Out:
# close            1.000000
# adj close        1.000000
# high             0.999535
# low              0.999532
# open             0.998976
# gdx_low          0.975561
# gdx_close        0.975459
# gdx_high         0.975255
# gdx_adj close    0.974980
# gdx_open         0.974824
# sf_low           0.947842
# sf_price         0.947420
# sf_open          0.945557
# sf_high          0.945203
# eg_low           0.863917
# eg_open          0.862900
# eg_close         0.862770
# eg_high          0.861479
# eg_ajclose       0.859850
# plt_price        0.775861
# plt_high         0.775481
# plt_low          0.773993
# plt_open         0.773760
# usdi_low         0.722078
# usdi_price       0.721569
# usdi_open        0.720140
# usdi_high        0.720023
# of_high          0.711334
# of_price         0.710693
# of_open          0.709096
# of_low           0.708266
# sf_volume        0.706505
# date             0.686721
# sp_high          0.684904
# sp_open          0.684618
# sp_close         0.684284
# sp_low           0.683750
# sp_ajclose       0.666071
# uso_adj close    0.635675
# uso_close        0.635675
# uso_high         0.635311
# uso_open         0.635197
# uso_low          0.634732
# os_high          0.632001
# os_price         0.630817
# os_open          0.630046
# os_low           0.629083
# dj_open          0.588800
# dj_high          0.588778
# dj_ajclose       0.588411
# dj_close         0.588411
# dj_low           0.588157
# eu_high          0.582969
# eu_price         0.581036
# eu_open          0.579036
# eu_low           0.577000
# gdx_volume       0.514616
# Name: close, dtype: float64

# %% [markdown]
# ### Features mit der niedrigsten Korrelation zum Goldpreis "Close"

# %%
all_corr[all_corr < 0.5]
# Out:
# usb_high       0.464116
# uso_volume     0.456193
# usb_price      0.441347
# usb_open       0.440822
# usb_low        0.417352
# volume         0.246778
# sp_volume      0.241949
# of_volume      0.225436
# pld_high       0.217490
# pld_open       0.216426
# pld_low        0.214919
# pld_price      0.213179
# usdi_volume    0.205954
# dj_volume      0.155526
# eg_volume      0.126586
# y              0.082588
# rho_price      0.073140
# os_trend       0.059510
# of_trend       0.048205
# sf_trend       0.028100
# pld_trend      0.026536
# usb_trend      0.025933
# eu_trend       0.019913
# usdi_trend     0.016641
# plt_trend      0.011355
# Name: close, dtype: float64

# %% [markdown]
# ## Visualisierung der einzelnen Datenquellen

# %%
colors = [ "blue","orange","green","red","purple","cyan"]

date_time_key = "date"

def show_raw_visualization(data):
    time_data = data[date_time_key]
    fig, axes = plt.subplots(
        nrows=3, ncols=2, figsize=(15, 20), dpi=80, facecolor="w", edgecolor="k"
    )
    for i in range(len(feature_keys)):
        key = feature_keys[i]
        c = colors[i % (len(colors))]
        t_data = data[key]
        t_data.index = time_data
        t_data.head()
        ax = t_data.plot(
            ax=axes[i // 2, i % 2],
            color=c,
            title="{} - {}".format(titles[i], key),
            rot=25,
        )
        ax.legend([titles[i]])
    plt.tight_layout()

# %% [markdown]
# ### Gold

# %%
titles = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
feature_keys = ['open', 'high', 'low', 'close', 'adj close', 'volume']
show_raw_visualization(df)

# %%
# Kaggle:
#    The historical data of Gold ETF were fetched from Yahoo finance.
#    Closing price of a stock is the price of that stock at the close of the trading day.
#    Adjusted closing price takes into account factors such as dividends, stock splits 
#    and new stock offerings to determine a value.

# Wir wählen als voherzusagenden Wert den Wert "Close", da die zusätzlichen Einflussgrößen, 
# die "Adj Close" beeinflussen, für uns weniger relevant sind.

# "Close" wird also unsere Targetspalte "y"

# Aus den Spalten "High" und "Low" kann die Volatilität berechnet werden.
# Bewegt sich der prognostizierte Wert innerhalb der Volatilität, ist unser Ergebnis "Preis bleibt gleich".
# Bewegt er sich außerhalb der Volatilität, liefern wir "Preis fällt" oder "Preis steigt".

# Die anderen Features sind nicht relevant und werden entfernt.
# Auch das Handelsvolumen korreliert nicht signifikant mit dem Preis und wird entfernt.

# %% [markdown]
# ### S&P 500 Index

# %%
titles = ['SP_open', 'SP_high', 'SP_low', 'SP_close', 'SP_Ajclose','SP_volume']
feature_keys = ['sp_open', 'sp_high', 'sp_low', 'sp_close', 'sp_ajclose','sp_volume']
show_raw_visualization(df)

# %%
# Es handelt sich hier um Werte des S&P 500 Index.

# Die Features sind alle sehr ähnlich. Wir wählen nur die Spalte "Close" und entfernen die anderen,
# auch die Spalte "Volume", die mit dem Goldpreis nicht signifikant korreliert

# %% [markdown]
# ### Dow Jones Index

# %%
titles = ['DJ_open', 'DJ_high', 'DJ_low', 'DJ_close', 'DJ_Ajclose', 'DJ_volume']
feature_keys = ['dj_open', 'dj_high', 'dj_low', 'dj_close', 'dj_ajclose', 'dj_volume']
show_raw_visualization(df)

# %%
# Es handelt sich hier um Werte des Dow Jones Index.

# Wir verfahren wie beim S & P Index und wählen nur die Spalte "Close"

# %% [markdown]
# ### Eldorado Gold Corporation

# %%
titles = ['EG_open', 'EG_high', 'EG_low', 'EG_close', 'EG_Ajclose', 'EG_volume']
feature_keys = ['eg_open', 'eg_high', 'eg_low', 'eg_close', 'eg_ajclose', 'eg_volume']
show_raw_visualization(df)

# %%
# Es handelt sich hier um Werte der Eldorado Gold Corporation.

# Wir verfahren wie bei den Aktienindizes und wählen nur die Spalte "Close"

# %% [markdown]
# ### EUR USD Exchange Rate

# %%
titles = ['EU_Price', 'EU_open', 'EU_high', 'EU_low', 'EU_Trend']
feature_keys = ['eu_price', 'eu_open', 'eu_high', 'eu_low', 'eu_trend']
show_raw_visualization(df)

# %%
# Es handelt sich hier um den Wechselkurs EUR - USD.

# Wir verwenden statt diesem Wechselkurs den USD Index Price, siehe weiter unten

# %% [markdown]
# ### Brent Crude Oil Futures

# %%
titles = ['OF_Price','OF_Open', 'OF_High', 'OF_Low', 'OF_Volume', 'OF_Trend' ]
feature_keys = ['OF_Price','OF_Open', 'OF_High', 'OF_Low', 'OF_Volume', 'OF_Trend']
show_raw_visualization(df)

# %%
# Es handelt sich hier um Kurswerte der Brent Crude Oil Futures.
# Auch hier wählen wir nur die Spalte "OF Price", und löschen die anderen zu ähnlichen Spalten.
# "OF Trend" und "OF Volume" korrelieren (fast) nicht mit dem Goldpreis.

# %% [markdown]
# ### Crude Oil WTI USD

# %%
titles = ['OS_Price','OS_Open', 'OS_High', 'OS_Low', 'OS_Trend' ]
feature_keys = ['OS_Price','OS_Open', 'OS_High', 'OS_Low', 'OS_Trend']
show_raw_visualization(df)

# %%
# Es handelt sich hier um Kurswerte des Crude Oil WTI USD.
# Auch hier wählen wir nur die Spalte "OS Price", und löschen die anderen zu ähnlichen Spalten.
# "OS Trend" korreliert (fast) nicht mit dem Goldpreis.

# %% [markdown]
# ### Silver Futures

# %%
titles = ['SF_Price', 'SF_Open','SF_High', 'SF_Low', 'SF_Volume', 'SF_Trend' ]
feature_keys = ['SF_Price', 'SF_Open','SF_High', 'SF_Low', 'SF_Volume', 'SF_Trend']
show_raw_visualization(df)

# %%
# Es handelt sich hier um Kurswerte der Silver Futures, also im Prinzip um den "Silberpreis".
# Auch hier wählen wir nur die Spalte "SF Price", und löschen die anderen zu ähnlichen Spalten.

# Das Handelsvolumen "SF Volume" korreliert immerhin mit 0.7 mit dem Goldpreis und könnte eine Rolle spielen.
# Daher könnte die Spalte evtl. beibehalten werden.

# "SF Trend" korreliert (fast) nicht mit dem Goldpreis.

# %% [markdown]
# ### US Bond Rate data

# %%
titles = ['USB_Price', 'USB_Open','USB_High', 'USB_Low', 'USB_Trend' ]
feature_keys = ['USB_Price', 'USB_Open','USB_High', 'USB_Low', 'USB_Trend']
show_raw_visualization(df)

# %%
# Es handelt sich hier um US Bond Rate data, also um Preise amerikanischer Staatsanleihen,
# die die allgemeine Zinsentwicklung abbilden

# Wir wählen nur die Spalte "USB Price", obwohl diese nur mit 0.44 mit dem Goldpreis korreliert

# %% [markdown]
# ### Platinum Price

# %%
titles = ['PLT_Price', 'PLT_Open', 'PLT_High','PLT_Low', 'PLT_Trend' ]
feature_keys = ['PLT_Price', 'PLT_Open', 'PLT_High','PLT_Low', 'PLT_Trend']
show_raw_visualization(df)

# %%
# Hier handelt es sich um den Platin-Preis
# Wir verwenden nur die Spalte "PLT Price". Er korreliert relativ stark mit dem Goldpreis (0.776).

# %% [markdown]
# ### Palladium price and Rhodium price

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'adj close', 'volume',
#        'sp_open', 'sp_high', 'sp_low', 'sp_close', 'sp_ajclose', 'sp_volume',
#        'dj_open', 'dj_high', 'dj_low', 'dj_close', 'dj_ajclose', 'dj_volume',
#        'eg_open', 'eg_high', 'eg_low', 'eg_close', 'eg_ajclose', 'eg_volume',
#        'eu_price', 'eu_open', 'eu_high', 'eu_low', 'eu_trend', 'of_price',
#        'of_open', 'of_high', 'of_low', 'of_volume', 'of_trend', 'os_price',
#        'os_open', 'os_high', 'os_low', 'os_trend', 'sf_price', 'sf_open',
#        'sf_high', 'sf_low', 'sf_volume', 'sf_trend', 'usb_price', 'usb_open',
#        'usb_high', 'usb_low', 'usb_trend', 'plt_price', 'plt_open', 'plt_high',
#        'plt_low', 'plt_trend', 'pld_price', 'pld_open', 'pld_high', 'pld_low',
#        'pld_trend', 'rho_price', 'usdi_price', 'usdi_open', 'usdi_high',
#        'usdi_low', 'usdi_volume', 'usdi_trend', 'gdx_open', 'gdx_high',
#        'gdx_low', 'gdx_close', 'gdx_adj close', 'gdx_volume', 'uso_open',
#        'uso_high', 'uso_low', 'uso_close', 'uso_adj close', 'uso_volume', 'y',
#        'volatility'],
#       dtype='object')

# %%
df.rho_price
# Out:
# date
# 2011-12-15    1425.0
# 2011-12-16    1400.0
# 2011-12-19    1400.0
# 2011-12-20    1400.0
# 2011-12-21    1400.0
#                ...
# 2018-12-24    2480.0
# 2018-12-26    2480.0
# 2018-12-27    2470.0
# 2018-12-28    2460.0
# 2018-12-31    2460.0
# Name: rho_price, Length: 1718, dtype: float64

# %%
titles = ['PLD_Price', 'PLD_Open', 'PLD_High', 'PLD_Low','PLD_Trend', 'RHO_PRICE' ]
feature_keys = ['pld_price', 'pld_open', 'pld_high', 'pld_low','pld_trend', 'rho_price']
show_raw_visualization(df)

# %%
# Hier handelt es sich um den Palladium Preis und den Rhodium Preis
# Die Preise korrelieren kaum mit dem Goldpreis (Rhodium 0.09)

# Wir verwenden daher die Splaten nicht

# %% [markdown]
# ### US dollar Index Price

# %%
titles = ['USDI_Price', 'USDI_Open', 'USDI_High','USDI_Low', 'USDI_Volume', 'USDI_Trend' ]
feature_keys = ['USDI_Price', 'USDI_Open', 'USDI_High', 'USDI_Low', 'USDI_Volume', 'USDI_Trend']
show_raw_visualization(df)

# %%
# The U.S. dollar index allows traders to monitor the value of the USD 
# compared to a basket of selected currencies. 

# Wir verwenden hier die Spalte "USDI Price". Sie korreliert relativ startk mit dem Goldpreis (0.72)
# Volume und Trend korrelieren kaum mit dem Goldpreis.

# %% [markdown]
# ### Gold Miners ETF

# %%
titles = ['GDX_Open', 'GDX_High','GDX_Low', 'GDX_Close', 'GDX_Adj Close', 'GDX_Volume' ]
feature_keys = ['GDX_Open', 'GDX_High','GDX_Low', 'GDX_Close', 'GDX_Adj Close', 'GDX_Volume']
show_raw_visualization(df)

# %%
# Hier handelt es sich um einen ETF, der verschiedene Goldminen umfasst
# Er korreliert natürlich stark mit dem Goldpreis (0.97)

# Wir verwenden die Spalte "GDX Close"

# %% [markdown]
# ### Oil ETF USO (United States Oil Fund)

# %%
titles = ['USO_Open','USO_High', 'USO_Low', 'USO_Close', 'USO_Adj Close', 'USO_Volume' ]
feature_keys = ['USO_Open','USO_High', 'USO_Low', 'USO_Close', 'USO_Adj Close', 'USO_Volume']
show_raw_visualization(df)

# %%
# Hier handelt es sich um einen weiteren Oil ETF
# Wir verwenden nur die Spalte "USO Close"

# %% [markdown]
# ### y und Volatility

# %%
titles = ['y', 'Volatility' ]
feature_keys = ['y', 'Volatility']
show_raw_visualization(df)

# %% [markdown]
# ### Zur Auswahl stehende Spalten

# %%
# (Gold) Close wird für die Zielspalte verwendet, aber evtl. klassifiziert (sinkt, bleibt gleich, steigt)
# bzw. wird Gold Open vom Folgetag herangezogen

# (Gold) High und Low werden für die Berechnung der Volatilität verwendet

# Korrelation mit "Close":

# GDX Close (Gold Miners ETF)  0.975
# SF Price (Silberpreis) 0.947
# SF Volume (Silber Handelsvolumen) 0.71
# EG Close (Eldorado Gold Corp.) 0.863
# PLT Price (Platinpreis) 0.776
# USDI Price (USD Preis-Index) 0.722
# OF Price (Oil Futures) 0.71
# SP Close (S&P 500) 0.684
# USO Close (United States Oil Fund) 0.636
# OS Price (Crude Oil WTI )  0.63
# DJ Close (Dow Jones) 0.588
# USB Price (US Bonds) 0.441

# Korrelation mit "y":

# PLT Open (Platinpreis) 0.102
# Open (Goldpreis) 0.095
# SF Open (Silberpreis)  0.092
# EU Open (USD EUR Wechselkurs) 0.08
# OF Open (Oil Futures) 0.075
## USDI Open (USD Preis-Index) 0.074
## OS Open (Crude Oil WTI)  0.072
## USO Open (United States Oil Fund)  0.064

# Volume (Gold)
# Volatility

# %%
# Ausgewählte Spalten in die Inputdaten X übernehmen

X = df.loc[:, ["PLT_Open", "Open", "SF_Open", "USB_Trend", "EU_open", "OF_Open", "Volume", "Volatility" ]]
y = df["y"]

# %%
X

# %%
import pickle

with open('X.pickle', 'wb') as f:    
    # Einpacken
    pickle.dump(X, f, pickle.HIGHEST_PROTOCOL)

# %%
file = open('X.pickle','rb')
XX = pickle.load(file)
file.close()
XX

# %%
df.y.hist(bins=50)
